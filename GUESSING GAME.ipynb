# %%
print("WELCOME TO GUESS ME!")
print("I'm thinking of a number between 1 and 100")
print("If your guess is more than 10 away from my number, I'll tell you you're COLD")
print("If your guess is within 10 of my number, I'll tell you you're WARM")
print("If your guess is farther than your most recent guess, I'll say you're getting COLDER")
print("If your guess is closer than your most recent guess, I'll say you're getting WARMER")
print("LET'S PLAY!")
# Out:
# WELCOME TO GUESS ME!
# I'm thinking of a number between 1 and 100
# If your guess is more than 10 away from my number, I'll tell you you're COLD
# If your guess is within 10 of my number, I'll tell you you're WARM
# If your guess is farther than your most recent guess, I'll say you're getting COLDER
# If your guess is closer than your most recent guess, I'll say you're getting WARMER
# LET'S PLAY!

# %%
import random
num=random.randint(1,100)

guesses=[]


while True:
    
    guess=int(input('I am thinking a number between 1 and 100.\nWhat is your guess? '))
    
    if guess<1 or guess>100:
        print('Out of bounds!')
        continue
        
    guesses.append(guess) 
    
    if guess==num:
        print(f'CONGRATULATIONS!You guessed it right and you needed {len(guesses)} guesses.')
        break
        
    if len(guesses)>=2:
        if abs(num-guesses[-1])<abs(num-guesses[-2]):
            print('WARMER!')
        else:
            print('COLDER!')
    else:
        if abs(num-guesses[-1])>10:
            print('COLD!')
        else:
            print('WARM!')
# Out:
# I am thinking a number between 1 and 100.
# What is your guess? 50
# WARM!
# I am thinking a number between 1 and 100.
# What is your guess? 60
# WAEMER!
# I am thinking a number between 1 and 100.
# What is your guess? 65
# COLDER!
# I am thinking a number between 1 and 100.
# What is your guess? 64
# WAEMER!
# I am thinking a number between 1 and 100.
# What is your guess? 62
# WAEMER!
# I am thinking a number between 1 and 100.
# What is your guess? 61
# WAEMER!
# I am thinking a number between 1 and 100.
# What is your guess? 59
# CONGRATULATIONS!You guessed it right and you needed 7 guesses.
